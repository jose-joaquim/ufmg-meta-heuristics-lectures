# %%
import polars as pl
import matplotlib.pyplot as plt


df = pl.read_csv('data.txt',separator=" ", schema={'Initial Population' : pl.Float64, 'Final Population' : pl.Float64})
df.describe()

fig, axs = plt.subplots(1, 1)
fig.tight_layout()
axs[0].boxplot([df['Initial Population'].to_list(), df['Final Population'].to_list()])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x147677d50>,
#   <matplotlib.lines.Line2D at 0x147680a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x147680d90>,
#   <matplotlib.lines.Line2D at 0x147681810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x147667f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x147682150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x147682d50>],
#  'means': []}
